# %%
import re

import pandas as pd

# %%
f=open('/WhatsApp Chat with PMEC-CSE-20222026.txt','r',encoding='utf-8')

# %%
data=f.read()

# %%
print(data)
# Out:
# 30/11/2022, 1:49 pm - Rajat Kumar Dalai created group "PMEC-CSE-2022/2026"
# 30/11/2022, 1:49 pm - You were added
# 23/05/2024, 2:47 pm - +91 89260 42140: This message was deleted
# 23/05/2024, 3:01 pm - Purusottam Reddy: https://docs.google.com/forms/d/e/1FAIpQLScb1ZNMPRIJ9QpqzZqpQNeBz8oMpH-qESqSfjoEJtMVlzKu4g/viewform
# 28/05/2024, 8:50 am - +91 72056 86932: <Media omitted>
# 28/05/2024, 8:50 am - +91 72056 86932: <Media omitted>
# 28/05/2024, 8:50 am - +91 72056 86932: <Media omitted>
# 28/05/2024, 8:50 am - +91 72056 86932: <Media omitted>
# 28/05/2024, 8:50 am - +91 72056 86932: <Media omitted>
# 28/05/2024, 8:50 am - +91 72056 86932: <Media omitted>
# 28/05/2024, 8:50 am - +91 72056 86932: <Media omitted>
# 28/05/2024, 2:04 pm - Jagruti Cr Mam: <Media omitted>
# 28/05/2024, 2:04 pm - Jagruti Cr Mam: <Media omitted>
# 28/05/2024, 2:04 pm - Jagruti Cr Mam: <Media omitted>
# 28/05/2024, 2:04 pm - Jagruti Cr Mam: <Media omitted>
# ...
