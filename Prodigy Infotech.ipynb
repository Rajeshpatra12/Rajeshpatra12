# %% [markdown]
# #**PRODIGY INFOTECH**
# #**TASK DONE BY :- RAJESH PATRA**
# #**PROBLEM STATEMENT**
# ## Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %%
# importing all library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('World Development.csv')
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# ...

# %%
# shape check
df.shape
# Out:
# (266, 68)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.154480e+08  1.170538e+08  1.192160e+08  1.218878e+08  1.245835e+08
# std    3.626523e+08  3.671660e+08  3.738303e+08  3.824608e+08  3.911397e+08
# min    2.715000e+03  2.970000e+03  3.264000e+03  3.584000e+03  3.922000e+03
# 25%    5.152028e+05  5.255230e+05  5.363018e+05  5.475875e+05  5.593638e+05
# 50%    3.659633e+06  3.747132e+06  3.831900e+06  3.919710e+06  4.010150e+06
# 75%    2.686293e+07  2.761326e+07  2.837302e+07  2.915448e+07  2.995223e+07
# max    3.021529e+09  3.062769e+09  3.117373e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.273111e+08  1.301581e+08  1.330127e+08  1.359425e+08  1.389705e+08
# ...

# %%
df.isna().sum()
# Out:
# Country Name      0
# Indicator Code    0
# 1960              2
# 1961              2
# 1962              2
#                  ..
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# 2023              1
# Length: 66, dtype: int64

# %%
# Drop unuseful columns
df.drop(columns=['Country Name', 'Indicator Code'],inplace=True)

# %%
df.sample()
# Out:
#                                           Country Name Indicator Code  \
# 161  Middle East & North Africa (excluding high inc...    SP.POP.TOTL
#
#            1960        1961         1962         1963         1964  \
# 161  97138700.0  99660885.0  102288730.0  105030514.0  107860080.0
#
#             1965         1966         1967  ...         2014         2015  \
# 161  110767062.0  113811829.0  117013328.0  ...  377506892.0  384230039.0
#
#             2016         2017         2018         2019         2020  \
# 161  390998434.0  397804712.0  404775501.0  411833977.0  418461302.0
#
#             2021         2022         2023
# 161  424980589.0  432229148.0  440118189.0
#
# [1 rows x 66 columns]

# %%
# filter data for total population
total_population_df=df[df['Indicator Code']=='SP.POP.TOTL']
total_population_df
# Out:
#                     Country Name Indicator Code         1960         1961  \
# 0                          Aruba    SP.POP.TOTL      54922.0      55578.0
# 1    Africa Eastern and Southern    SP.POP.TOTL  130072080.0  133534923.0
# 2                    Afghanistan    SP.POP.TOTL    9035043.0    9214083.0
# 3     Africa Western and Central    SP.POP.TOTL   97630925.0   99706674.0
# 4                         Angola    SP.POP.TOTL    5231654.0    5301583.0
# ..                           ...            ...          ...          ...
# 261                       Kosovo    SP.POP.TOTL     984846.0    1011421.0
# 262                  Yemen, Rep.    SP.POP.TOTL    5532301.0    5655232.0
# 263                 South Africa    SP.POP.TOTL   16440172.0   16908035.0
# 264                       Zambia    SP.POP.TOTL    3153729.0    3254086.0
# 265                     Zimbabwe    SP.POP.TOTL    3809389.0    3930401.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
# sort data based on total population for 2023
total_population_sort = total_population_df.sort_values(by='2023',ascending=False)
total_population_sort
# Out:
#                  Country Name Indicator Code          1960          1961  \
# 259                     World    SP.POP.TOTL  3.021529e+09  3.062769e+09
# 103          IDA & IBRD total    SP.POP.TOTL  2.289188e+09  2.321079e+09
# 140       Low & middle income    SP.POP.TOTL  2.106419e+09  2.136241e+09
# 156             Middle income    SP.POP.TOTL  1.970293e+09  1.996885e+09
# 102                 IBRD only    SP.POP.TOTL  1.893701e+09  1.915613e+09
# ..                        ...            ...           ...           ...
# 147  St. Martin (French part)    SP.POP.TOTL  4.250000e+03  4.386000e+03
# 188                     Palau    SP.POP.TOTL  9.328000e+03  9.555000e+03
# 179                     Nauru    SP.POP.TOTL  4.607000e+03  4.774000e+03
# 245                    Tuvalu    SP.POP.TOTL  5.598000e+03  5.648000e+03
# 110            Not classified    SP.POP.TOTL           NaN           NaN
#
#              1962          1963          1964          1965          1966  \
# ...

# %% [markdown]
# # **get top 10 countries with the highest population for 2023**

# %%
# get top 10 countries with the highest population for 2023
top_ten_countries = total_population_sort.head(10)
print("Top Ten Counteies Of Total Population:-")
print(top_ten_countries)
# Out:
# Top Ten Counteies Of Total Population:-
#                    Country Name Indicator Code          1960          1961  \
# 259                       World    SP.POP.TOTL  3.021529e+09  3.062769e+09
# 103            IDA & IBRD total    SP.POP.TOTL  2.289188e+09  2.321079e+09
# 140         Low & middle income    SP.POP.TOTL  2.106419e+09  2.136241e+09
# 156               Middle income    SP.POP.TOTL  1.970293e+09  1.996885e+09
# 102                   IBRD only    SP.POP.TOTL  1.893701e+09  1.915613e+09
# 62   Early-demographic dividend    SP.POP.TOTL  9.689094e+08  9.941768e+08
# 139         Lower middle income    SP.POP.TOTL  8.190472e+08  8.396491e+08
# 249         Upper middle income    SP.POP.TOTL  1.151246e+09  1.157236e+09
# 63          East Asia & Pacific    SP.POP.TOTL  1.042838e+09  1.044750e+09
# 142   Late-demographic dividend    SP.POP.TOTL  1.094880e+09  1.096959e+09
#
#              1962          1963          1964          1965          1966  \
# ...

# %% [markdown]
# # **Data visualization**

# %%
# Data visualization
def add_value_labels(ax,spacing=10):
    for rect in ax.patches:
        x=rect.get_x()+rect.get_width()/2
        y=rect.get_height()-3

        va='bottom' if y>=0 else 'top'
        label= '()'.format(y)
        y_shift = spacing * (1 if y >= 0 else -1)
        ax.annotate(label,(x,y),xytext=(0,y_shift),textcoords="offset points",ha='center',va=va)

# %% [markdown]
# #**Top ten counteirs of total population in year 2023 and 2000**

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2023',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population (2023)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# <ipython-input-67-b1b49d4be912>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='2023',y="Country Name",data=top_ten_countries,palette="coolwarm")
# <ipython-input-67-b1b49d4be912>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='2000',y="Country Name",data=top_ten_countries,palette="coolwarm")

# %% [markdown]
# # **Top ten countries of total population in year 1999 and 1989**

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# <ipython-input-44-78a46cb3f516>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='1999',y="Country Name",data=top_ten_countries,palette="coolwarm")
# <ipython-input-44-78a46cb3f516>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='1989',y="Country Name",data=top_ten_countries,palette="coolwarm")

# %% [markdown]
# # **Top ten counteirs of total population in year 1960 and 2022**

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1960',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2023',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# <ipython-input-68-2751dd9519ba>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='1960',y="Country Name",data=top_ten_countries,palette="coolwarm")
# <ipython-input-68-2751dd9519ba>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='2023',y="Country Name",data=top_ten_countries,palette="coolwarm")

# %% [markdown]
# # **get bottom 10 countries with the highest population**

# %%
# sort data based on total population for 2023
total_population_sort_bt = total_population_df.sort_values(by='2023',ascending=True)
total_population_sort_bt
# Out:
#                  Country Name Indicator Code          1960          1961  \
# 245                    Tuvalu    SP.POP.TOTL  5.598000e+03  5.648000e+03
# 179                     Nauru    SP.POP.TOTL  4.607000e+03  4.774000e+03
# 188                     Palau    SP.POP.TOTL  9.328000e+03  9.555000e+03
# 147  St. Martin (French part)    SP.POP.TOTL  4.250000e+03  4.386000e+03
# 212                San Marino    SP.POP.TOTL  1.542800e+04  1.579900e+04
# ..                        ...            ...           ...           ...
# 156             Middle income    SP.POP.TOTL  1.970293e+09  1.996885e+09
# 140       Low & middle income    SP.POP.TOTL  2.106419e+09  2.136241e+09
# 103          IDA & IBRD total    SP.POP.TOTL  2.289188e+09  2.321079e+09
# 259                     World    SP.POP.TOTL  3.021529e+09  3.062769e+09
# 110            Not classified    SP.POP.TOTL           NaN           NaN
#
#              1962          1963          1964          1965          1966  \
# ...

# %%
top_ten_bt_countries = total_population_sort_bt.head(10)
print("Top Ten Bottom Counteies Of Total Population:-")
print(top_ten_bt_countries)
# Out:
# Top Ten Bottom Counteies Of Total Population:-
#                  Country Name Indicator Code     1960     1961     1962  \
# 245                    Tuvalu    SP.POP.TOTL   5598.0   5648.0   5699.0
# 179                     Nauru    SP.POP.TOTL   4607.0   4774.0   4979.0
# 188                     Palau    SP.POP.TOTL   9328.0   9555.0   9793.0
# 147  St. Martin (French part)    SP.POP.TOTL   4250.0   4386.0   4527.0
# 212                San Marino    SP.POP.TOTL  15428.0  15799.0  16183.0
# 84                  Gibraltar    SP.POP.TOTL  21839.0  21872.0  22197.0
# 255    British Virgin Islands    SP.POP.TOTL   7950.0   8034.0   8070.0
# 149                    Monaco    SP.POP.TOTL  21808.0  21901.0  22078.0
# 137             Liechtenstein    SP.POP.TOTL  16451.0  16877.0  17443.0
# 155          Marshall Islands    SP.POP.TOTL  14703.0  15219.0  15755.0
#
#         1963     1964     1965     1966     1967  ...     2014     2015  \
# ...

# %% [markdown]
# # **Bottom ten countries of total population in year 2023 and 2000**

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2023',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population (2023)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# <ipython-input-70-85a38892cbec>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='2023',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
# <ipython-input-70-85a38892cbec>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='2000',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")

# %% [markdown]
# # **Bottom ten counteirs of total population in year 1999 and 1989**

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# <ipython-input-71-68684c2f4fa3>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='1999',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
# <ipython-input-71-68684c2f4fa3>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='1989',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")

# %% [markdown]
# # **Bottom ten counteirs of total population in year 1960 and 2023**

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1960',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population (1960)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2023',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population in 2023")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# <ipython-input-72-b096db3f1c0b>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='1960',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
# <ipython-input-72-b096db3f1c0b>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='2023',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")

# %% [markdown]
# # **extracted top ten countries with highest male population**

# %%
df.sample(10)
# Out:
#          Country Name Indicator Code        1960        1961        1962  \
# 10            Armenia    SP.POP.TOTL   1863705.0   1927484.0   1991689.0
# 189  Papua New Guinea    SP.POP.TOTL   1995110.0   2046127.0   2093919.0
# 226        Seychelles    SP.POP.TOTL     41700.0     42889.0     44042.0
# 20         Bangladesh    SP.POP.TOTL  51828660.0  53310348.0  54881146.0
# 157   North Macedonia    SP.POP.TOTL   1435059.0   1455171.0   1471745.0
# 122   Kyrgyz Republic    SP.POP.TOTL   2172300.0   2255900.0   2333400.0
# 6             Andorra    SP.POP.TOTL      9510.0     10283.0     11086.0
# 119             Japan    SP.POP.TOTL  93216000.0  94055000.0  94933000.0
# 72           Ethiopia    SP.POP.TOTL  21376693.0  21906102.0  22465126.0
# 188             Palau    SP.POP.TOTL      9328.0      9555.0      9793.0
#
#            1963        1964        1965        1966        1967  ...  \
# 10    2056023.0   2120135.0   2183635.0   2246159.0   2307492.0  ...
# ...

# %%
# filter data for total male population
total_population_male=df[df['Indicator Code']=='SP.POP.TOTL.MA.IN']
total_population_male
# Out:
# Empty DataFrame
# Columns: [Country Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# Index: []
#
# [0 rows x 66 columns]

# %%
# sort data based on total population for 2023
total_population_sort_ma = total_population_male.sort_values(by='2023',ascending=False)
total_population_sort_ma
# Out:
# Empty DataFrame
# Columns: [Country Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# Index: []
#
# [0 rows x 66 columns]

# %%
# get top 10 countries with the highest population for 2023
top_ten_male_countries = total_population_sort_ma.head(10)
print("Top Ten male Counteies Of Total Population:-")
print(top_ten_male_countries)
# Out:
# Top Ten male Counteies Of Total Population:-
# Empty DataFrame
# Columns: [Country Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# Index: []
#
# [0 rows x 66 columns]

# %% [markdown]
# # **Thank you**
